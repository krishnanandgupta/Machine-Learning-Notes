# %% [markdown]
# # Pandas 1

# %%
# Pandas : It offers data structures and operations for manipulating numerical tables and time series.

# Pandas module : 

import pandas as pd

# %%
# Reading file from pandas. Put Backslash in URL & don't put space in name

pd.read_csv("H:/Sample-Spreadsheet-1000-rows.csv")
# Out:
#      S.no                                               Name  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                Ambasdor    Min      Avg     Max  Score            Branch  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
#storing the data in variable

df=pd.read_csv("H:/Sample-Spreadsheet-1000-rows.csv")

# %%
#Note: dataframe is data type.It is in tabular format

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Show some record from top, by deafult it shows 5 record

df.head(2)
# Out:
#    S.no                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
#
#              Ambasdor  Min     Avg     Max  Score   Branch  \
# 0  Muhammed MacIntyre    3 -213.25   38.94  35.00  Nunavut
# 1        Barry French  293  457.81  208.16  68.02  Nunavut
#
#                  Category  Percentage
# 0  Storage & Organization        0.80
# 1              Appliances        0.58

# %%
#Show some record from bottom, by deafult it shows 5 record

df.tail()
# Out:
#      S.no                                               Name  \
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#               Ambasdor    Min     Avg    Max  Score            Branch  \
# 995      Dennis Bolton  48165 -147.27   6.48   9.54  British Columbia
# 996  Anthony O'Donnell  48197  154.74  40.97  14.45  British Columbia
# 997     Barbara Fisher  48484   67.96  16.48   1.99  British Columbia
# 998     Barbara Fisher  48484  133.83  20.24   6.67  British Columbia
# 999     Barbara Fisher  48484  153.80  18.97   9.03  British Columbia
#
#                  Category  Percentage
# 995                 Paper        0.37
# 996    Office Furnishings        0.57
# 997  Computer Peripherals        0.42
# ...

# %%
#By default first row is column name. For NO COLUMN use header=None

df=pd.read_csv("H:/Sample-Spreadsheet-1000-rows.csv",header=None )

# %%
df
# Out:
#          0                                                  1  \
# 0     S.no                                               Name
# 1        1   Eldon Base for stackable storage shelf, platinum
# 2        2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 3        3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl
# 4        4                                               R380
# ...    ...                                                ...
# 996    996                                         Xerox 1905
# 997    997              Dana Halogen Swing-Arm Architect Lamp
# 998    998                               Maxell DVD-RAM Discs
# 999    999  DAX Contemporary Wood Frame with Silver Metal ...
# 1000  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                        2      3        4       5      6                 7  \
# 0               Ambasdor    Min      Avg     Max  Score            Branch
# ...

# %%
# Give own column name. Use NAMEs

df=pd.read_csv("H:/Sample-Spreadsheet-1000-rows.csv",header=None,names=['a','b','c','d','e','f','g','h','i','j'] )

# %%
df
# Out:
#          a                                                  b  \
# 0     S.no                                               Name
# 1        1   Eldon Base for stackable storage shelf, platinum
# 2        2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 3        3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl
# 4        4                                               R380
# ...    ...                                                ...
# 996    996                                         Xerox 1905
# 997    997              Dana Halogen Swing-Arm Architect Lamp
# 998    998                               Maxell DVD-RAM Discs
# 999    999  DAX Contemporary Wood Frame with Silver Metal ...
# 1000  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                        c      d        e       f      g                 h  \
# 0               Ambasdor    Min      Avg     Max  Score            Branch
# ...

# %%
#skip rows

df=pd.read_csv("H:/Sample-Spreadsheet-1000-rows.csv",skiprows=[1,3,5])
df
# Out:
#      S.no                                               Name  \
# 0       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1       4                                               R380
# 2       6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 3       7  Angle-D Binders with Locking Rings, Label Holders
# 4       8            SAFCO Mobile Desk Side File, Wire Frame
# ..    ...                                                ...
# 992   996                                         Xerox 1905
# 993   997              Dana Halogen Swing-Arm Architect Lamp
# 994   998                               Maxell DVD-RAM Discs
# 995   999  DAX Contemporary Wood Frame with Silver Metal ...
# 996  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#               Ambasdor    Min      Avg     Max  Score            Branch  \
# 0         Barry French    293   457.81  208.16  68.02           Nunavut
# 1        Clay Rozendal    483  1198.97  195.99   3.99           Nunavut
# ...

# %%
#Na_Values is used to put values as NULL

df=pd.read_csv("H:/Sample-Spreadsheet-1000-rows.csv",na_values=["Xerox 1905"])
df
# Out:
#      S.no                                               Name  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                                NaN
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                Ambasdor    Min      Avg     Max  Score            Branch  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
#Read data from excel 

ex=pd.read_excel("C:/Users/MIRACLE COMPUTERS/Downloads/file_example_XLS_50.xls")

# %%
ex
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
#How to read different sheet in excel 

ex=pd.read_excel("C:/Users/MIRACLE COMPUTERS/Downloads/file_example_XLS_50.xls",sheet_name="Sheet2")
ex
# Out:
#        Roll     Name
# 0  20120126  Krishna

# %%
#read all the tables from html page

ht=pd.read_html('https://www.basketball-reference.com/leaders/orb_top_10.html')
ht
# Out:
# [     Season   Lg                 1st                                2nd  \
#  0   2020-21  NBA     C. Capela (297)                    E. Kanter (284)
#  1   2019-20  NBA  H. Whiteside (258)                  A. Drummond (250)
#  2   2018-19  NBA   A. Drummond (423)                     S. Adams (391)
#  3   2017-18  NBA   A. Drummond (399)                     S. Adams (384)
#  4   2016-17  NBA   A. Drummond (345)                    R. Gobert (314)
#  5   2015-16  NBA   A. Drummond (395)  R. Lopez (268), T. Thompson (268)
#  6   2014-15  NBA   A. Drummond (437)                    D. Jordan (397)
#  7   2013-14  NBA   A. Drummond (440)                    D. Jordan (331)
#  8   2012-13  NBA   Z. Randolph (310)                  T. Thompson (306)
#  9   2011-12  NBA    D. Cousins (265)                      J. Noah (242)
#  10  2010-11  NBA       K. Love (330)                  Z. Randolph (326)
#  11  2009-10  NBA   Z. Randolph (330)                    D. Howard (284)
# ...

# %%
type(ht)
# Out:
# list

# %%
#Find total table in that html page

len(ht)
# Out:
# 1

# %%
#How to get first table of that html page. It works as same as list 

ht[0]
# Out:
#      Season   Lg                 1st                                2nd  \
# 0   2020-21  NBA     C. Capela (297)                    E. Kanter (284)
# 1   2019-20  NBA  H. Whiteside (258)                  A. Drummond (250)
# 2   2018-19  NBA   A. Drummond (423)                     S. Adams (391)
# 3   2017-18  NBA   A. Drummond (399)                     S. Adams (384)
# 4   2016-17  NBA   A. Drummond (345)                    R. Gobert (314)
# 5   2015-16  NBA   A. Drummond (395)  R. Lopez (268), T. Thompson (268)
# 6   2014-15  NBA   A. Drummond (437)                    D. Jordan (397)
# 7   2013-14  NBA   A. Drummond (440)                    D. Jordan (331)
# 8   2012-13  NBA   Z. Randolph (310)                  T. Thompson (306)
# 9   2011-12  NBA    D. Cousins (265)                      J. Noah (242)
# 10  2010-11  NBA       K. Love (330)                  Z. Randolph (326)
# 11  2009-10  NBA   Z. Randolph (330)                    D. Howard (284)
# ...

# %%
#Use tab as seperator live URL 

a=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",sep='\t')

# %%
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#To check datatype

a.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#List of column

a.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#to fetch multilple columnn

a[['Survived','Parch']]
# Out:
#      Survived  Parch
# 0           0      0
# 1           1      0
# 2           1      0
# 3           1      0
# 4           0      0
# ..        ...    ...
# 151         1      0
# 152         0      0
# 153         0      2
# 154         0      0
# 155         0      1
#
# [156 rows x 2 columns]
